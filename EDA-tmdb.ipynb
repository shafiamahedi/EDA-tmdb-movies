# %% [markdown]
# # VERZEO MINI PROJECT
#
# > The goal of the project is to go through the dataset and do data analysis by cleaning the data and perform EDA.

# %% [markdown]
# ### Questions :
# > 1. Which movie had the most profit during 2000-2005?
# > 2. Which are the movies with the second lowest and second highest budget?
# > 3. Which are the movies with most and least earned revenue?
# > 4. What is the average runtime of movies in the year 2000?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing dataset and inspecting the data

# %%
movies=pd.read_csv('tmdb-movies.csv')
movies.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies.tail(5)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
# ...

# %%
movies.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
movies.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
movies.shape
# Out:
# (10866, 21)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
movies.describe(include= 'all')
# Out:
#                    id    imdb_id    popularity        budget       revenue  \
# count    10866.000000      10856  10866.000000  1.086600e+04  1.086600e+04
# unique            NaN      10855           NaN           NaN           NaN
# top               NaN  tt0411951           NaN           NaN           NaN
# freq              NaN          2           NaN           NaN           NaN
# mean     66064.177434        NaN      0.646441  1.462570e+07  3.982332e+07
# std      92130.136561        NaN      1.000185  3.091321e+07  1.170035e+08
# min          5.000000        NaN      0.000065  0.000000e+00  0.000000e+00
# 25%      10596.250000        NaN      0.207583  0.000000e+00  0.000000e+00
# 50%      20669.000000        NaN      0.383856  0.000000e+00  0.000000e+00
# 75%      75610.000000        NaN      0.713817  1.500000e+07  2.400000e+07
# max     417859.000000        NaN     32.985763  4.250000e+08  2.781506e+09
#
# ...

# %%
# checking null values
movies.isnull()
# Out:
#           id  imdb_id  popularity  budget  revenue  original_title   cast  \
# 0      False    False       False   False    False           False  False
# 1      False    False       False   False    False           False  False
# 2      False    False       False   False    False           False  False
# 3      False    False       False   False    False           False  False
# 4      False    False       False   False    False           False  False
# ...      ...      ...         ...     ...      ...             ...    ...
# 10861  False    False       False   False    False           False  False
# 10862  False    False       False   False    False           False  False
# 10863  False    False       False   False    False           False  False
# 10864  False    False       False   False    False           False  False
# 10865  False    False       False   False    False           False  False
#
#        homepage  director  tagline  ...  overview  runtime  genres  \
# ...

# %%
# sum of rows in each column with null values
movies.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# ## Performing Data cleaning and EDA on dataset

# %%
#number of duplicate rows
sum(movies.duplicated())
# Out:
# 1

# %%
#delete duplicate rows
movies.drop_duplicates(inplace = True)

# %%
print("After deleting duplicate rows : ",movies.shape)
# Out:
# After deleting duplicate rows :  (10865, 21)

# %%
#drop columns that are not necessary
movies_df= movies.drop(['homepage','tagline', 'overview','budget_adj','revenue_adj'],axis=1)

# %%
movies_df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
avg = int(np.mean(movies_df['budget']))

# %%
movies_df['budget'] = movies_df['budget'].replace(0,avg)

# %%
avg = int(np.mean(movies_df['revenue']))

# %%
movies_df['revenue'] = movies_df['revenue'].replace(0,avg)

# %%
movies_df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598   14624286    39826896
# 10862   20379  tt0060472    0.065543   14624286    39826896
# 10863   39768  tt0060161    0.065141   14624286    39826896
# 10864   21449  tt0061177    0.064317   14624286    39826896
# 10865   22293  tt0060666    0.035919      19000    39826896
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %% [markdown]
# ## 1. Which movie had the most profit during 2000-2005?

# %%
profit = movies_df['revenue']-movies_df['budget']
movies_df['profit'] = profit
movies_df.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# ...

# %%
p = movies_df[(movies_df.release_year>=2000)&(movies_df.release_year<=2005)]
p
# Out:
#          id    imdb_id  popularity     budget    revenue  \
# 2633    120  tt0120737    8.575419   93000000  871368364
# 2634    671  tt0241527    8.021423  125000000  976475550
# 2635   1018  tt0166924    4.436367   15000000   20117339
# 2636    141  tt0246578    3.851009    6000000    1270522
# 2637    585  tt0198781    3.204295  115000000  562816256
# ...     ...        ...         ...        ...        ...
# 8883  36047  tt0163676    0.015997   15000000    5217498
# 8884  97351  tt0222270    0.006865   14624286   39826896
# 8885  20438  tt0234853    0.005784   14624286   39826896
# 8886  18292  tt0262432    0.080819   14624286   39826896
# 8887  44756  tt0250440    0.004010   14624286   39826896
#
#                                          original_title  \
# 2633  The Lord of the Rings: The Fellowship of the Ring
# 2634           Harry Potter and the Philosopher's Stone
# 2635                                   Mulholland Drive
# ...

# %%
pro = p[p.profit==p.profit.max()]
print("Movie that had the most profit during 2000-2005 is\n")
pro.iloc[:,[5,16]]
# Out:
# Movie that had the most profit during 2000-2005 is
#                                      original_title      profit
# 4949  The Lord of the Rings: The Return of the King  1024888979

# %% [markdown]
# ## 2. Which are the movies with the second lowest and second highest budget?

# %%
movies_df.sort_values('budget')
# Out:
#           id    imdb_id  popularity     budget     revenue  \
# 3581   59296  tt1436559    0.520430          1        1378
# 2618   39964  tt0120836    0.090186          1         100
# 3065   12689  tt0963743    0.472691          1    39826896
# 1151  287524  tt2165765    0.177102          1    39826896
# 8944   14373  tt0082250    0.464188          2          16
# ...      ...        ...         ...        ...         ...
# 6570    1452  tt0348150    1.957331  270000000   391081192
# 14     99861  tt2395427    5.944927  280000000  1405035767
# 7387     285  tt0449088    4.965391  300000000   961000000
# 3375    1865  tt1298650    4.955130  380000000  1021683000
# 2244   46528  tt1032751    0.250540  425000000    11087569
#
#                                    original_title  \
# 3581                      Love, Wedding, Marriage
# 2618                                 Lost & Found
# 3065           Angus, Thongs and Perfect Snogging
# 1151                                  Fear Clinic
# ...

# %%
df_bud = movies_df.drop_duplicates(subset='budget', keep="first")

# %%
movies_df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598   14624286    39826896
# 10862   20379  tt0060472    0.065543   14624286    39826896
# 10863   39768  tt0060161    0.065141   14624286    39826896
# 10864   21449  tt0061177    0.064317   14624286    39826896
# 10865   22293  tt0060666    0.035919      19000    39826896
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df_bud
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# 5      281957  tt1663202    9.110700  135000000   532950503
# ...       ...        ...         ...        ...         ...
# 10820   13377  tt0060345    1.227582     315000    39826896
# 10827    2661  tt0060153    0.410366    1377800    39826896
# 10829    6644  tt0061619    0.395668    4653000     6000000
# 10848    2161  tt0060397    0.207257    5115000    12000000
# 10865   22293  tt0060666    0.035919      19000    39826896
#
#                         original_title  \
# 0                       Jurassic World
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# 5                         The Revenant
# ...

# %%
df_bud = df_bud.sort_values('budget')
df_bud
# Out:
#           id    imdb_id  popularity     budget     revenue  \
# 1151  287524  tt2165765    0.177102          1    39826896
# 8944   14373  tt0082250    0.464188          2          16
# 2398   39356  tt1560139    0.028456          3          43
# 1313  286101  tt2664838    0.002922          5    39826896
# 8235   25066  tt0114609    0.105894          6          11
# ...      ...        ...         ...        ...         ...
# 6570    1452  tt0348150    1.957331  270000000   391081192
# 14     99861  tt2395427    5.944927  280000000  1405035767
# 7387     285  tt0449088    4.965391  300000000   961000000
# 3375    1865  tt1298650    4.955130  380000000  1021683000
# 2244   46528  tt1032751    0.250540  425000000    11087569
#
#                                    original_title  \
# 1151                                  Fear Clinic
# 8944                                 Death Wish 2
# 2398                                          Boy
# 1313                  Des Lendemains Qui Chantent
# ...

# %%
print("The second lowest budget movie is\n")
df_bud.iloc[1:2,[3,5]]
# Out:
# The second lowest budget movie is
#       budget original_title
# 8944       2   Death Wish 2

# %%
print("The second largest budget movie is\n")
df_bud.iloc[-2:-1,[3,5]]
# Out:
# The second largest budget movie is
#          budget                               original_title
# 3375  380000000  Pirates of the Caribbean: On Stranger Tides

# %% [markdown]
# ## 3. Which are the movies with most and least earned revenue?

# %%
print("Most earned revenue movie is\n")
max_rev = movies_df[movies_df.revenue == movies_df.revenue.max()]
max_rev.iloc[:,[4,5]]
# Out:
# Most earned revenue movie is
#          revenue original_title
# 1386  2781505847         Avatar

# %%
print("Least earned revenue movies are\n")
min_rev = movies_df[movies_df.revenue==movies_df.revenue.min()]
min_rev.iloc[:,[4,5]]
# Out:
# Least earned revenue movies are
#       revenue   original_title
# 5067        2  Shattered Glass
# 8142        2         Mallrats

# %% [markdown]
# ## 4. What is the average runtime of movies in the year 2000?

# %%
print("The average runtime of movies in the year 2000 is\n")
av = movies_df[movies_df.release_year==2000]
av["runtime"].mean()
# Out:
# The average runtime of movies in the year 2000 is
# 103.77973568281938
